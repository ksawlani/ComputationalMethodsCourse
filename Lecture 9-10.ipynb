# %% [markdown]
# ## Lecture 9
#
# Image processing

# %%
import scipy as sp
from numpy.fft import *

# %%
photo = imread('data/baby.png')
imshow(photo)

# %%
def rgb2gray(rgb):

    r, g, b = rgb[:,:,0], rgb[:,:,1], rgb[:,:,2]
    gray = 0.2989 * r + 0.5870 * g + 0.1140 * b

    return gray

photo_bw = rgb2gray(photo)
imshow(photo_bw, cmap="gray")

# %% [markdown]
# Fourier transform of image.

# %%
photo_t = fftshift(fft2(photo_bw))
imshow(log(abs(photo_t)))

# %% [markdown]
# Add noise to image.

# %%
photo_noise = photo_bw + random.randn(*shape(photo_bw))*.2

# %%
imshow(photo_noise, cmap='gray')

# %% [markdown]
# Fourier transform noisy image.

# %%
photo_noiset = fftshift(fft2(photo_noise))
imshow(log(abs(photo_noiset)))
xlim(400,600)
ylim(600,800)
# Out:
# (600, 800)

# %% [markdown]
# ## Lecture 10
#
# Linear filtering of images.

# %% [markdown]
# Create filter for noisy image. Try a gaussian in the center of the image.

# %%
x_coord = arange(photo_noiset.shape[0])
y_coord = arange(photo_noiset.shape[1])
kx,ky = meshgrid(x_coord, y_coord, indexing='ij')
kx.shape
# Out:
# (1440, 1080)

# %%
F = exp(-0.000001*(kx - 540)**2 - 0.000001*(ky - 720)**2)

# %%
photo_noiset_filtered = photo_noiset * F
photo_filtered = ifft2(fftshift(photo_noiset_filtered))
imshow(abs(photo_filtered), cmap='gray')
